# %%
#we want to dig into the world of text analytics which encompasses a wide range topics from Natural Processing Language to text sentiment analysis. 
#why we want to learn about text analytics? with the myraid volumne of data in the form of text originated from variety of sources, we want to be assured about the veracity of our understanding of the data. 
#This demands new way of analysis that traditionaly was not easily produceable.  
#We are going to use pandas package. 
import pandas as pd
import numpy as np

# %%
train=pd.read_csv('C:/Users/Fahimeh.Pouryani/Downloads/train.csv',sep=',',encoding='latin-1')

# %%
train.describe()
# Out:
#               ItemID     Sentiment
# count   99989.000000  99989.000000
# mean    50005.110042      0.564632
# std     28865.894393      0.495808
# min         1.000000      0.000000
# 25%     25009.000000      0.000000
# 50%     50006.000000      1.000000
# 75%     75003.000000      1.000000
# max    100000.000000      1.000000

# %%
train
# Out:
#        ItemID  Sentiment                                      SentimentText
# 0           1          0                       is so sad for my APL frie...
# 1           2          0                     I missed the New Moon trail...
# 2           3          1                            omg its already 7:30 :O
# 3           4          0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4           5          0           i think mi bf is cheating on me!!!   ...
# 5           6          0                  or i just worry too much?
# 6           7          1                 Juuuuuuuuuuuuuuuuussssst Chillin!!
# 7           8          0         Sunny Again        Work Tomorrow  :-|  ...
# 8           9          1        handed in my uniform today . i miss you ...
# 9          10          1           hmmmm.... i wonder how she my number @-)
# 10         11          0                      I must think about positive..
# ...

# %%
#one of the most basic thing we can do for text analytics, we can extract the number of words in each tweats.
#we use lambda here which is an alternative way of creating funtions. I think they are udeful for program control flow. I am still learning about this feature. We will have one exercise on Lambda. Stay tuned!

train['word_count']=train['SentimentText'].apply(lambda x: len(str(x).split(" ")))

# %%
train[['SentimentText','word_count']].head()
# Out:
#                                        SentimentText  word_count
# 0                       is so sad for my APL frie...          28
# 1                     I missed the New Moon trail...          25
# 2                            omg its already 7:30 :O          19
# 3            .. Omgaga. Im sooo  im gunna CRy. I'...          36
# 4           i think mi bf is cheating on me!!!   ...          24

# %%
#the objective of running analytics on any kinds of data is to derive meaningful information about the data such as the didstribution of a particular pattern.
#hence first we evaluate the data to understand the profiling charactristics of the content.
#we start with data profiling. extract the information about the basic details of the data.
#we can also calculate the number of characters in each tweet.One way to do this to calculate the length of the tweet.
train['char_count']=train['SentimentText'].str.len()-train['SentimentText'].str.len()
train[['SentimentText','char_count']].head()
# Out:
#                                        SentimentText  char_count
# 0                       is so sad for my APL frie...           0
# 1                     I missed the New Moon trail...           0
# 2                            omg its already 7:30 :O           0
# 3            .. Omgaga. Im sooo  im gunna CRy. I'...           0
# 4           i think mi bf is cheating on me!!!   ...           0

# %%
#This includes spaces. We can remove it and rerun the analysis.
##train['word_count_nospace']=len(train['SentimentText'])-train['SentimentText'].count(' ')

# %%
#we can profile the data furthur and calculate the average word length of each tweet.
#Encountered errors for using split() funtion.
#https://towardsdatascience.com/pandas-tips-and-tricks-33bcc8a40bb9
#Realized that the conversion is the culprit so to speak, then did this: sentence.split()--> str(sentence).split()
#It threw another error which was the main cause of the error: Miss to wrap train[avg_word] with quotation mark.
#that didn't work

def avg_word(sentence):
    words=sentence.split()
    return (sum(len(word) for word in words)/len(words))
    
train['avg_word']=train['SentimentText'].apply(lambda x:avg_word(x))#note that we use lambda to call another function.
train[['SentimentText','avg_word']].head()
# Out:
#                                        SentimentText  avg_word
# 0                       is so sad for my APL frie...  4.857143
# 1                     I missed the New Moon trail...  4.500000
# 2                            omg its already 7:30 :O  3.800000
# 3            .. Omgaga. Im sooo  im gunna CRy. I'...  3.880000
# 4           i think mi bf is cheating on me!!!   ...  3.333333

# %%
#Stop Words are words which do not contain important significance to be used in Search Queries--http://xpo6.com/list-of-english-stop-words/wikipedia
#how to spot them and remove them
#we are going to import stopwords from  NLTK, which is a basic NLP library in python.
from nltk.corpus import stopwords

# %%
stop=stopwords.words('english')
train['stopword']=train['SentimentText'].apply(lambda x:len([x for x in x.split() if x in stop]))
train[['SentimentText','stopword']].head()
# Out:
#                                        SentimentText  stopword
# 0                       is so sad for my APL frie...         4
# 1                     I missed the New Moon trail...         1
# 2                            omg its already 7:30 :O         1
# 3            .. Omgaga. Im sooo  im gunna CRy. I'...         7
# 4           i think mi bf is cheating on me!!!   ...         3

# %%
train['hashtag']=train['SentimentText'].apply(lambda x: len([x for x in x.split() if x.startswith('#')]))
train[['SentimentText','hashtag']].head()
# Out:
#                                        SentimentText  hashtag
# 0                       is so sad for my APL frie...        0
# 1                     I missed the New Moon trail...        0
# 2                            omg its already 7:30 :O        0
# 3            .. Omgaga. Im sooo  im gunna CRy. I'...        0
# 4           i think mi bf is cheating on me!!!   ...        0

# %%
train['isitdigit']=train['SentimentText'].apply(lambda x:len([x for x in x.split() if x.isdigit()]))
train[['SentimentText','isitdigit']].head()
# Out:
#                                        SentimentText  isitdigit
# 0                       is so sad for my APL frie...          0
# 1                     I missed the New Moon trail...          0
# 2                            omg its already 7:30 :O          0
# 3            .. Omgaga. Im sooo  im gunna CRy. I'...          1
# 4           i think mi bf is cheating on me!!!   ...          0

# %%
train['isuppercase']=train['SentimentText'].apply(lambda x:len([x for x in x.split() if x.isupper()]))
train[['SentimentText','isuppercase']].head()
# Out:
#                                        SentimentText  isuppercase
# 0                       is so sad for my APL frie...            1
# 1                     I missed the New Moon trail...            1
# 2                            omg its already 7:30 :O            1
# 3            .. Omgaga. Im sooo  im gunna CRy. I'...            1
# 4           i think mi bf is cheating on me!!!   ...            1

# %%
#https://stackoverflow.com/questions/20989115/collapse-and-lambda-s-joins-split-or-lambda-s-s
#next we try to clean up the data and only retain the data that could yield meaningful insight about the text.
#we first need to lower case all the words in the text
train['SentimentText']=train['SentimentText'].apply(lambda x:" ".join(x.lower() for x in x.split()))
train['SentimentText'].head()
# Out:
# 0             is so sad for my apl friend.............
# 1                     i missed the new moon trailer...
# 2                              omg its already 7:30 :o
# 3    .. omgaga. im sooo im gunna cry. i've been at ...
# 4               i think mi bf is cheating on me!!! t_t
# Name: SentimentText, dtype: object

# %%
#remove trivials like punctuation
train['SentimentText']=train['SentimentText'].str.replace(['\w\s'],'')
train['SentimentText'].head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-3bad3efea678> in <module>()
#       1 #remove trivials like punctuation
# ----> 2 train['SentimentText']=train['SentimentText'].str.replace(['\w\s'],'')
#       3 train['SentimentText'].head()
#
# c:\users\fahimeh.pouryani\appdata\local\continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3608         if (name in self._internal_names_set or name in self._metadata or
#    3609                 name in self._accessors):
# -> 3610             return object.__getattribute__(self, name)
#    3611         else:
#    3612             if name in self._info_axis:
#
# c:\users\fahimeh.pouryani\appdata\local\continuum\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, instance, owner)
#      52             # this ensures that Series.str.<method> is well defined
# ...

# %%
#I am convinced that I should have an exercise focused on lambda. It is very powerful, yet not very intuitive. 
#in this case lambda x: " ".join(x for x in x.split(), after a long search I figured out that this is putting everything back together, implicated by " ".join(...).whew!
stop=stopwords.words('english')
train['SentimentText']=train['SentimentText'].apply(lambda x:" ".join(x for x in x.split() if x not in stop))
train['SentimentText'].head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-29e504f1fab3> in <module>()
#       2 #in this case lambda x: " ".join(x for x in x.split(), after a long search I figured out that this is putting everything back together, implicated by " ".join(...).whew!
#       3 stop=stopwords.words('english')
# ----> 4 train['SentimentText']=train['SentimentText'].apply(lambda x:" ".join(x for x in x.split() if x not in stop))
#       5 train['SentimentText'].head()
#
# c:\users\fahimeh.pouryani\appdata\local\continuum\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# ...

# %%
#the syntax above throwing me errors. what's wrong? 
#it turns out that the removal created some NAN in the data.
#we need to clean that up first
#train=train[train['SentimentText'].notnull()]
train
# Out:
#        ItemID  Sentiment  SentimentText  word_count  char_count   avg_word  \
# 0           1          0            NaN          28           0   4.857143
# 1           2          0            NaN          25           0   4.500000
# 2           3          1            NaN          19           0   3.800000
# 3           4          0            NaN          36           0   3.880000
# 4           5          0            NaN          24           0   3.333333
# 5           6          0            NaN          23           0   3.333333
# 6           7          1            NaN           9           0  16.500000
# 7           8          0            NaN          28           0   4.857143
# 8           9          1            NaN          16           0   3.800000
# 9          10          1            NaN          14           0   4.125000
# 10         11          0            NaN          11           0   5.000000
# ...

# %%
stop=stopwords.words('english')
train['SentimentText']=train['SentimentText'].apply(lambda x:" ".join(x for x in x.split() if x not in stop))
train['SentimentText'].head()
# Out:
# Series([], Name: SentimentText, dtype: float64)

# %%
train['SentimentText']
# Out:
# Series([], Name: SentimentText, dtype: float64)

# %%
train
# Out:
# Empty DataFrame
# Columns: [ItemID, Sentiment, SentimentText, word_count, char_count, avg_word, hashtag, stopword, isitdigit, isuppercase]
# Index: []
